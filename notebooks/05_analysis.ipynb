# %% [markdown]
# # 05_analysis
#
# Evaluation & analysis notebook.

# %%
print('Load models from ../models and features from ../data/features.csv to run evaluation')
# Out:
# Load models from ../models and features from ../data/features.csv to run evaluation
